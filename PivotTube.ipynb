# %%
import pandas as pd

# Initial data
data1 = {'Make': ['utv/atv'], 
         'Model': ['all models'], 
         'Vendor Code': ['NACH'], 
         'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04176-1'], 
         'AD Item Number': ['128242'], 
         'Vendor Notes': [pd.NA], 
        }

# List of models
new_list_models = [
    
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 570',
'Ranger RZR 570',
'Ranger RZR 570 EPS Trail LE',
'RZR 570',
'RZR 570 EPS Trail LE',
'RZR 570 EPS LE',
'RZR 570 EPS Trail',
'RZR 570 EPS',
'RZR 570 Premium',
'RZR 570 Trail',
'Ranger RZR 4 800 Gordon Edition',
'Ranger RZR 4 800 EPS Robby Gordon',
'Ranger RZR 4 800 EPS Robby Gordon LE',
'Ranger RZR 4 800',
'Ranger RZR 4 800 EPS LE',
'RZR 4 800 EPS LE',
'Ranger RZR 800',
'Ranger RZR 800 S',
'Ranger RZR 800 EPS',
'Ranger RZR 800 SW Military',
'Ranger RZR 800 S LE',
'Ranger RZR 800 EPS LE',
'Ranger RZR 800 LE',
'RZR 800',
'RZR 800 EPS LE',
'RZR 800 XC Edition',
'Ranger RZR S 800 EPS LE',
'RZR S 800 EPS LE',
'RZR S 800',
'Ranger 900 XP',
'Ranger 900 XP EPS',
'Ranger 900 XP EPS Browning LE',
'Ranger 900 XP EPS LE',
'Ranger 900 XP LE',
'Ranger 900 XP Bronze Mist LE',
'Ranger 900 XP Deluxe',
'Ranger 900 XP EPS Northstar Edition',
'Ranger 900 XP EPS Hunter Deluxe Edition',
'Ranger 900 XP EPS Deluxe',
'Ranger 900 XP EPS Hunter Edition',
'Ranger Crew 900-5',
'Ranger Crew 900-5 EPS',
'Ranger Crew 900-6',
'Ranger Crew 900-6 EPS'
'RZR 4 900 EPS LE',
'RZR 4 900 EPS',
'Ranger RZR XP 900',
'Ranger RZR XP 900 LE',
'Ranger RZR XP 900 EPS Walker Evans LE',
'Ranger RZR XP 900 EPS LE',
'Ranger RZR XP 900 HO Jagged X Edition',
'RZR 900 EPS LE',
'RZR 900',
'RZR 900 XC Edition',
'RZR 900 EPS Trail',
'RZR 900 EPS XC Edition',
'RZR 900 EPS Trail Fox Edition LE',
'RZR 900 EPS',
'RZR 900 Premium',
'RZR 900 Fox Edition',
'Ranger 1000',
'Ranger 1000 EPS',
'Ranger 1000 Premium',
'Ranger 1000 Premium + Winter Prep Package',
'Ranger Diesel',
'Ranger Diesel Crew',
'Ranger Diesel HST',
'Ranger Diesel HST Deluxe',
'Ranger XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS High Lifter Edition',
'Ranger XP 1000 EPS Ranch Edition',
'Ranger XP 1000 EPS Hunter Edition',
'Ranger XP 1000 EPS',
'Ranger XP 1000',
'Ranger XP 1000 EPS Premium',
'Ranger XP 1000 EPS 20th Anniversary',
'Ranger XP 1000 Premium',
'Ranger XP 1000 NorthStar Edition',
'Ranger XP 1000 High Lifter Edition',
'Ranger XP 1000 Texas Edition',
'Ranger XP 1000 NorthStar Premium',
'Ranger XP 1000 NorthStar Edition Trail Boss',
'Ranger XP 1000 NorthStar Ultimate',
'Ranger XP 1000 Trail Boss',
'Ranger XP 1000 Waterfowl Edition',
'Ranger XP 1000 Big Game Edition',
'Ranger Diesel HST Deluxe'   

]  

# Range of years
years = list(range(2010, 2022))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
    dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#          Make                              Model Vendor Code  \
# 0     utv/atv           Ranger 570 EPS Full-Size        NACH
# 1     utv/atv               Ranger 570 Full-Size        NACH
# 2     utv/atv          Ranger 570 Crew Full-Size        NACH
# 3     utv/atv      Ranger 570 Crew EPS Full-Size        NACH
# 4     utv/atv                         Ranger 570        NACH
# ...       ...                                ...         ...
# 1075  utv/atv  Ranger XP 1000 NorthStar Ultimate        NACH
# 1076  utv/atv          Ranger XP 1000 Trail Boss        NACH
# 1077  utv/atv   Ranger XP 1000 Waterfowl Edition        NACH
# 1078  utv/atv    Ranger XP 1000 Big Game Edition        NACH
# 1079  utv/atv           Ranger Diesel HST Deluxe        NACH
#
#                        Vendor Name         MPN AD Item Number Vendor Notes  \
# 0     NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 1     NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 2     NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 3     NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 4     NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# ...                            ...         ...            ...          ...
# 1075  NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 1076  NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 1077  NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 1078  NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
# 1079  NACHMAN INTERNATIONAL CO.LTD  AT-04176-1         128242         <NA>
#
#       Year
# 0     2010
# 1     2010
# 2     2010
# 3     2010
# 4     2010
# ...    ...
# 1075  2021
# 1076  2021
# 1077  2021
# 1078  2021
# 1079  2021
#
# [1080 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\04_Section 04 - Pivot Tube - in progress\Merge\1.csv"
final_df.to_csv(file_path, index=False)
